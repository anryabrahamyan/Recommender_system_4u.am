# %%
import os
os.chdir('..')

# %%
from src.recommender import Recommender

# %%
rec = Recommender()
# Out:
# C:\Users\Nitro\Desktop\marketing_analytics_group_project\Recommender_system_4u.am\src\recommender.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["item description"] = data["item description"].apply(lambda x : x.replace("\n\n\n", " "))
# C:\Users\Nitro\Desktop\marketing_analytics_group_project\Recommender_system_4u.am\src\recommender.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["item description"] = data["item description"].apply(lambda x : x.replace("\n", " "))
# ...

# %%
rec.predict(14)
# Out:
#         price  image similarities  name_similarities  ...         category         brand  weighted_sum
# 14   0.057134            1.000000           1.000000  ...              NaN           NaN      0.855138
# 39   0.051405            0.988413           0.807307  ...        jewellery  Less is more      0.739866
# 18   0.261700            0.988846           0.580044  ...  men accessories         Cluse      0.726368
# 51   0.039384            0.987831           0.817686  ...        jewellery    DF Project      0.628288
# 285  0.039384            0.988370           0.755324  ...              NaN           NaN      0.606999
#
# [5 rows x 16 columns]

# %%
#observing the individual items
print(rec.tabular.iloc[14])
print('--------------------')
print(rec.tabular.iloc[18])
# Out:
# product                         Bracelet  `Fossil Group`   JF02703040
# item_code                                                 00-00003027
# store                                                            Time
# url                 https://4u.am/en/product/bracelet-fossil-group...
# price                                                         33500.0
# item description    Brand:     Fossil Gender:     Men Country:    ...
# image url           https://static.4u.am/origin/product/1024/DwNro...
# category                                              men accessories
# brand                                                    Fossil Group
# Name: 20, dtype: object
# --------------------
# product                           Wristwatch `Emporio Armani` AR11180
# item_code                                                 00-00029962
# store                                                            Time
# url                 https://4u.am/en/product/wristwatch-emporio-ar...
# ...
